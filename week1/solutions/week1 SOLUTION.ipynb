# %% [markdown]
# # End of week 1 solution
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!
#
# After week 2 you'll be able to add a User Interface to this tool, giving you a valuable application.

# %%
# imports

from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

load_dotenv()
openai = OpenAI()

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# prompts

system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

# %%
# messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# Get gpt-4o-mini to answer, with streaming

stream = openai.chat.completions.create(model=MODEL_GPT, messages=messages,stream=True)
    
response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Certainly! Let's break down the code snippet you've provided:
#
# python
# yield from {book.get("author") for book in books if book.get("author")}
#
#
# ### Components Breakdown
#
# 1. **Set Comprehension**:
#     - The expression `{book.get("author") for book in books if book.get("author")}` is a *set comprehension*.
#     - This comprehension iterates over a collection called `books`, which is expected to be an iterable (like a list) of dictionaries.
#     - Each dictionary in `books` represents a book, and we are interested in the "author" key in these dictionaries.
#
# 2. **Key Methods and Functions**:
#     - `book.get("author")`: This method retrieves the value associated with the key "author" from the `book` dictionary. If "author" does not exist, it returns `None` (instead of raising a KeyError, which would happen if you used `book["author"]`).
#     - The expression `if book.get("author")` ensures that we're only including authors that actually exist; that is, we only want those books that have a defined author (i.e., not `None`).
#
# 3. **Creating a Set**:
#     - The outer `{...}` creates a set. A set is a collection type in Python that automatically eliminates duplicate entries. Thus, if multiple books have the same author, that author will only appear once in the resulting set.
#
# 4. **`yield from` Statement**:
#     - `yield from` is used in generator functions. It allows the generator to yield all values from another iterable.
#     - By using `yield from`, this code allows the surrounding generator function to yield each author from the set created by the comprehension.
#
# ### Putting It All Together
#
# - The entire line of code essentially does the following:
#   1. It iterates over each `book` in the `books` collection.
#   2. For each `book`, it checks if there is an "author". If there is, it retrieves that author's name.
#   3. It constructs a set of unique authors from the `books`.
#   4. Finally, it yields these authors one by one to whoever is iterating over the generator.
#
# ### Use Case and Importance
#
# - This line of code is useful when you want to extract a unique list of authors from a list of books while removing any duplicates and avoiding errors from missing author entries.
# - It efficiently handles missing data (by checking if the author is not `None`) and ensures that there’s no duplication (by using a set).
# - It is typically used in the context of a generator function, which allows lazy evaluation. This means authors are produced on-the-fly, which can be more memory efficient compared to creating a complete list all at once.
#
# ### Example of Use
#
# Suppose you have the following list of books:
#
# python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": "Author B"},
#     {"title": "Book 3", "author": None},
#     {"title": "Book 4", "author": "Author A"},
#     {"title": "Book 5", "author": "Author C"}
# ]
#
#
# When you execute the line of code within a generator function, it would create a set of authors: `{"Author A", "Author B", "Author C"}`. The `yield from` would then yield each of these authors one at a time.
#
# ### Final Notes
#
# - This snippet is a good example of Python's powerful data handling capabilities, showcasing list/set comprehensions and generator functions.
# - It's commonly used in scenarios where data is dynamic or potentially has missing fields, making it robust for various datasets.

# %%
# Get Llama 3.2 to answer

response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Get Llama 3.2 to answer
# ----> 3 response = ollama.chat(model=MODEL_LLAMA, messages=messages)
#       4 reply = response['message']['content']
#       5 display(Markdown(reply))
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/ollama/_client.py:342, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     297 def chat(
#     298   self,
#     299   model: str = '',
#    (...)    307   keep_alive: Optional[Union[float, str]] = None,
#     308 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     309   """
#     310   Create a chat response using the requested model.
#     311
#    (...)    340   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     341   """
# --> 342   return self._request(
#     343     ChatResponse,
#     344     'POST',
#     345     '/api/chat',
#     346     json=ChatRequest(
#     347       model=model,
#     348       messages=list(_copy_messages(messages)),
#     349       tools=list(_copy_tools(tools)),
#     350       stream=stream,
#     351       think=think,
#     352       format=format,
#     353       options=options,
#     354       keep_alive=keep_alive,
#     355     ).model_dump(exclude_none=True),
#     356     stream=stream,
#     357   )
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/ollama/_client.py:180, in Client._request(self, cls, stream, *args, **kwargs)
#     176         yield cls(**part)
#     178   return inner()
# --> 180 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/ollama/_client.py:126, in Client._request_raw(self, *args, **kwargs)
#     124   raise ResponseError(e.response.text, e.response.status_code) from None
#     125 except httpx.ConnectError:
# --> 126   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %% [markdown]
# # Congratulations!
#
# You could make it better by taking in the question using
# `my_question = input("Please enter your question:")`
#
# And then creating the prompts and making the calls interactively.
